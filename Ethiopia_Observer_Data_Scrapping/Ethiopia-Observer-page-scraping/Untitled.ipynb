# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Display all rows and full text in Jupyter
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)

# Request headers
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/137.0.0.0 Safari/537.36",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
    "Accept-Language": "en-US,en;q=0.9",
    "Referer": "https://google.com/"
}

# Website URL
url = "https://www.ethiopiaobserver.com/"

# Send request
response = requests.get(url, headers=headers)

# Check request status
print("Status Code:", response.status_code)

# Parse HTML
soup = BeautifulSoup(response.text, "html.parser")

# Lists to store data
title_list = []
image_list = []

# Find all articles
articles = soup.find_all("article")

# Extract data
for article in articles:
    h2_tag = article.find("h2")
    image_tag = article.find("img")

    if h2_tag and image_tag:
        a_tag = h2_tag.find("a")

        if a_tag:
            title = a_tag.text.strip()
            image_url = image_tag.get("src", "")

            title_list.append(title)
            image_list.append(image_url)

# Create DataFrame
df = pd.DataFrame({
    "Title": title_list,
    "Image_URL": image_list
})

# Display DataFrame
print("\nTotal Articles:", len(df))
print(df)

# Save to CSV
df.to_csv(
    "ethiopia_observer_articles.csv",
    index=False,
    encoding="utf-8-sig"
)

print("\nCSV file saved successfully!")
# Out:
# Status Code: 200
#
# Total Articles: 13
#                                                                       Title  \
# 0                              The overlooked conflict in the Amhara region
# 1   Fighting ends between federal forces and TPLF, but calm remains fragile
# 2              Calls for greater international attention to Amhara conflict
# 3                              The overlooked conflict in the Amhara region
# 4   Fighting ends between federal forces and TPLF, but calm remains fragile
# 5              Calls for greater international attention to Amhara conflict
# 6    Heavy fighting erupts near Sudan border as army and TPLF exchange fire
# 7            ከአሜሪካውያን ዘንድ ለእስራኤል የነበረው ድጋፍ እየቀነሰ መምጣቱ እንደሚያሳስባቸው ኔታንያሁ ገለፁ።
# 8     Ethiopian Airlines CEO says retirement due after final term extension
# 9           Ethiopian Airlines says Eritrea has frozen ticket sale revenues
# 10                  Ethiopian cinema on the Paris stage: a look at Zemetaye
# 11                                        በሙስና የተጨማለቁት ዶናልድ ትራምፕ እና ቤተሰቦቻቸው
# 12                        Tadesse Werede is under house arrest, reports say
#
#                                                                                                                                                              Image_URL
# 0                                                                  https://www.ethiopiaobserver.com/wp-content/uploads/2025/12/XPLX3XAX4JESZL6VUXQ5OQXL4I-883x450.avif
# 1                                                              https://i0.wp.com/www.ethiopiaobserver.com/wp-content/uploads/2022/01/Tigray.jpg?resize=624%2C351&ssl=1
# 2                                                                  https://www.ethiopiaobserver.com/wp-content/uploads/2025/12/R3IBMB4QSRHSVMVWC4AR3SGJOY-883x450.avif
# 3                                                                  https://www.ethiopiaobserver.com/wp-content/uploads/2025/12/XPLX3XAX4JESZL6VUXQ5OQXL4I-300x300.avif
# 4                                                              https://i0.wp.com/www.ethiopiaobserver.com/wp-content/uploads/2022/01/Tigray.jpg?resize=300%2C300&ssl=1
# 5                                                                  https://www.ethiopiaobserver.com/wp-content/uploads/2025/12/R3IBMB4QSRHSVMVWC4AR3SGJOY-300x300.avif
# 6                                                                 https://i0.wp.com/www.ethiopiaobserver.com/wp-content/uploads/2022/08/816.jpg?resize=300%2C300&ssl=1
# 7                                                            https://i0.wp.com/www.ethiopiaobserver.com/wp-content/uploads/2026/07/ml-7oJM_.jpg?resize=300%2C300&ssl=1
# 8                          https://i0.wp.com/www.ethiopiaobserver.com/wp-content/uploads/2026/07/facebook_1785402690644_7488521646986003805.jpg?resize=300%2C300&ssl=1
# 9                                                     https://i0.wp.com/www.ethiopiaobserver.com/wp-content/uploads/2026/05/HHN96qfW8AE6749.jpg?resize=300%2C300&ssl=1
# 10                                                  https://i0.wp.com/www.ethiopiaobserver.com/wp-content/uploads/2026/07/20260725_160345-1.jpg?resize=300%2C300&ssl=1
# 11  https://i0.wp.com/www.ethiopiaobserver.com/wp-content/uploads/2026/07/bfdfd9552b5b70f1e24d45b5906e4163d228b47814aa06301a4ea1e190367974.webp?resize=300%2C300&ssl=1
# 12                          https://i0.wp.com/www.ethiopiaobserver.com/wp-content/uploads/2026/07/1ad2c3c0-81b5-11f1-b976-0b9c15b0ccfc.jpg.webp?resize=300%2C300&ssl=1
#
# CSV file saved successfully!
