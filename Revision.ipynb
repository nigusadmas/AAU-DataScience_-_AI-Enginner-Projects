# %%
s = "Ababa"
print(s)
s = "Addis"
age = 25
city = "Ethiopia"
print(s,"Äbaba", city, age)
# Out:
# Ababa
# Addis Äbaba Ethiopia 25

# %%
for i in range(1, 5):
 for j in range(i):
     print(i, end=' ',)
 print()
# Out:
# 1
# 2 2
# 3 3 3
# 4 4 4 4

# %%
for letter in 'pythonforpython':
 if letter == 'y' or letter == 'o':
     continue
 print('Current Letter :', letter)
# Out:
# Current Letter : p
# Current Letter : t
# Current Letter : h
# Current Letter : n
# Current Letter : f
# Current Letter : r
# Current Letter : p
# Current Letter : t
# Current Letter : h
# Current Letter : n

# %%
names=['ababe','kebede','almaz','alemu']
print(names)
# Out:
# ['ababe', 'kebede', 'almaz', 'alemu']

# %%
names[0]='bezawit'

# %%
print(names)
# Out:
# ['bezawit', 'kebede', 'almaz', 'alemu']

# %%
names.append('solomon')

# %%
print(names)
# Out:
# ['bezawit', 'kebede', 'almaz', 'alemu', 'solomon']

# %%
names.insert(0,'Haile')

# %%
print(names)
# Out:
# ['Haile', 'bezawit', 'kebede', 'almaz', 'alemu', 'solomon']

# %%
number=[1,2,3,4,5,76]

# %%
print(number)
# Out:
# [1, 2, 3, 4, 5, 76]

# %%
names.extend(number)

# %%
print(names)
# Out:
# ['Haile', 'bezawit', 'kebede', 'almaz', 'alemu', 'solomon', 1, 2, 3, 4, 5, 76]

# %%
number
# Out:
# [1, 2, 3, 4, 5, 76]

# %%
number.extend(names)

# %%
print(number)
# Out:
# [1, 2, 3, 4, 5, 76, 'Haile', 'bezawit', 'kebede', 'almaz', 'alemu', 'solomon', 1, 2, 3, 4, 5, 76]

# %%
print(number)
# Out:
# [1, 2, 3, 4, 5, 76, 'Haile', 'bezawit', 'kebede', 'almaz', 'alemu', 'solomon', 1, 2, 3, 4, 5, 76]

# %%
print(number)
# Out:
# [1, 2, 3, 4, 5, 76, 'Haile', 'bezawit', 'kebede', 'almaz', 'alemu', 'solomon', 1, 2, 3, 4, 5, 76]

# %%
number.pop()
number.pop()
number.pop()
number.pop()
number.pop()
# Out:
# 2

# %%
print(number)
# Out:
# [1, 2, 3, 4, 5, 76, 'Haile', 'bezawit', 'kebede', 'almaz', 'alemu', 'solomon', 1]

# %%
number.pop(0)
# Out:
# 1

# %%
print(number)
# Out:
# [2, 3, 4, 5, 76, 'Haile', 'bezawit', 'kebede', 'almaz', 'alemu', 'solomon', 1]

# %%
# Lambeda function
c = [1, 2, 3, 4, 5, 6]
odd=filter(lambda x:x%2!=0,c)
print(list(odd))
# Out:
# [1, 3, 5]

# %%
even=filter(lambda Y:Y%2==0 , c)
print(list(even))
# Out:
# [2, 4, 6]

# %%
double=map(lambda T:T*3,c)
print(list(double))
# Out:
# [3, 6, 9, 12, 15, 18]

# %%
def abe():
    """This function performs Gretting"""
    print("Hello , Abe!")
abe()
# Out:
# Hello , Abe!

# %%
def evenOdd(y):
    if(y%2==0):
        return "Even" 
    else:
        return "Odd" 
print(evenOdd(10))
# Out:
# Even

# %%
def myFun(x, y=50):
    print("x: ", x)
    print("y: ", y)
myFun(10)
# Out:
# x:  10
# y:  50

# %%
# List comprehenssion 
data = [1, 2, 3, 4, 5, 6, 7, 8]
result=[value**2+value/2 for value in data]
print(result)
# Out:
# [1.5, 5.0, 10.5, 18.0, 27.5, 39.0, 52.5, 68.0]

# %%
datas=[2,3,4,5]
double=[val*2 for val in datas]
print(double)
# Out:
# [4, 6, 8, 10]

# %%
result=[value for value in range (0,15) if value%2==0]
print(result)
# Out:
# [0, 2, 4, 6, 8, 10, 12, 14]

# %%
text="Addis Ababa Unversity"
upper=lambda x:x.upper()
print(upper(text))
# Out:
# ADDIS ABABA UNVERSITY

# %%
# condition check using lambda function
evenOdd = lambda x: "Even" if x%2==0 else "odd"
print(evenOdd(4))
print(evenOdd(3))
print(evenOdd(10))
print(evenOdd(5))
# Out:
# Even
# odd
# Even
# odd

# %%
# Numpy Revision
import numpy as np
arr=np.array([
    [2,3,4,6,7,7,3],
    [3,56,7,88,99,32,5],
     [3,10,37,45,32,12,6]
]
    
)

print(arr)
print("==========================================")
print(arr.ndim)
print("==========================================")
print(arr*2)
print("==========================================")
print(arr.shape)
print("==========================================")
arr2 = arr[:2, ::3]
print(arr2)
print("==========================================")

print("="*40)
arr3=arr[:2,::2]
print(arr3)
print("="*40)
print(arr+1)
print("==========================================")
print(arr-10)
print("==========================================")
print(arr+arr)
# Out:
# [[ 2  3  4  6  7  7  3]
#  [ 3 56  7 88 99 32  5]
#  [ 3 10 37 45 32 12  6]]
# ...
# 2
# ...
# [[  4   6   8  12  14  14   6]
#  [  6 112  14 176 198  64  10]
#  [  6  20  74  90  64  24  12]]
# ...
# (3, 7)
# ...
# [[ 2  6  3]
#  [ 3 88  5]]
# ...
# [[ 2  4  7  3]
#  [ 3  7 99  5]]
# ...
# [[  3   4   5   7   8   8   4]
#  [  4  57   8  89 100  33   6]
#  [  4  11  38  46  33  13   7]]
# ...
# [[-8 -7 -6 -4 -3 -3 -7]
#  [-7 46 -3 78 89 22 -5]
#  [-7  0 27 35 22  2 -4]]
# ...
# [[  4   6   8  12  14  14   6]
#  [  6 112  14 176 198  64  10]
#  [  6  20  74  90  64  24  12]]

# %%
import numpy as np
x = np.array([1, 2])
print(x.dtype)
x = np.array([1.0, 2.0])
print(x.dtype)
x = np.array([1, 2], dtype = np.int64)
print(x.dtype)
# Out:
# int64
# float64
# int64

# %%
import numpy as np
arr1 = np.array([[4, 7], [2, 6]], dtype = np.int64)
arr2 = np.array([[3, 6], [2, 8]], dtype = np.int64) 

sum=np.add(arr1,arr2)
print(sum)

sum1=np.sum(arr1)
print(sum1)
sum2=np.sum(arr2)
print(sum2)

sqrt1=np.sqrt(arr1)
print(sqrt1)
# Out:
# [[ 7 13]
#  [ 4 14]]
# 19
# 19
# [[2.         2.64575131]
#  [1.41421356 2.44948974]]

# %%
# Pandas Revision
import pandas as pd
data = {'Name':['Michael', 'Eyob', 'Bethelhem', 'Martha'],
 'Department':['Computer Science', 'InformationTechnology', 'Information Systems', 'Computer Engineering'],
 'Age':[20, 21, 19, 18]}
df=pd.DataFrame(data)
print(df)
# Out:
#         Name             Department  Age
# 0    Michael       Computer Science   20
# 1       Eyob  InformationTechnology   21
# 2  Bethelhem    Information Systems   19
# 3     Martha   Computer Engineering   18

# %%
# to print specific column from a dataframe use the following line of code
print("Öne Column")
print(df["Name"])

print("================================")
print("Two column")
print(df[["Name" , "Department"]])

print("================================")
print("Three column")
print(df[["Name" , "Department","Age"]])
# Out:
# Öne Column
# 0      Michael
# 1         Eyob
# 2    Bethelhem
# 3       Martha
# Name: Name, dtype: object
# ...
# Two column
#         Name             Department
# 0    Michael       Computer Science
# 1       Eyob  InformationTechnology
# 2  Bethelhem    Information Systems
# 3     Martha   Computer Engineering
# ...
# Three column
#         Name             Department  Age
# 0    Michael       Computer Science   20
# 1       Eyob  InformationTechnology   21
# 2  Bethelhem    Information Systems   19
# 3     Martha   Computer Engineering   18

# %%
# To print  specific rows(Element) from a dataframe use the following line of code
print(df["Name"].loc[0])
print("="*30)
print(df.loc[0].T)
print("="*30)
print(df.loc[[0,1,2]])
# Out:
# Michael
# ...
# Name                   Michael
# Department    Computer Science
# Age                         20
# Name: 0, dtype: object
# ...
#         Name             Department  Age
# 0    Michael       Computer Science   20
# 1       Eyob  InformationTechnology   21
# 2  Bethelhem    Information Systems   19

# %%
# to check the missing value from a data frame
# df["notNull"]=df.notnull()
# df["isnull"]=df.isnull()
df
# Out:
#         Name             Department  Age
# 0    Michael       Computer Science   20
# 1       Eyob  InformationTechnology   21
# 2  Bethelhem    Information Systems   19
# 3     Martha   Computer Engineering   18

# %%
import pandas as pd
import numpy as np
dict = {'First Score':[100, 90, np.nan, 95],
 'Second Score': [30, 45, 56, np.nan],
 'Third Score':[np.nan, 40, 80, 98]}
df = pd.DataFrame(dict)
df.isnull()
# Out:
#    First Score  Second Score  Third Score
# 0        False         False         True
# 1        False         False        False
# 2         True         False        False
# 3        False          True        False

# %%
import pandas as pd
import numpy as np
data = {'First Score':[100, 90, np.nan, 95],
 'Second Score': [30, 45, 56, np.nan],
 'Third Score':[np.nan, 40, 80, 98]}
df = pd.DataFrame(data)

# %%
df
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2          NaN          56.0         80.0
# 3         95.0           NaN         98.0

# %%
df.isnull()
# Out:
#    First Score  Second Score  Third Score
# 0        False         False         True
# 1        False         False        False
# 2         True         False        False
# 3        False          True        False

# %%
df.isnull().sum()
# Out:
# First Score     1
# Second Score    1
# Third Score     1
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(3)

# %%
# df.fillna(0)
df
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2          NaN          56.0         80.0
# 3         95.0           NaN         98.0

# %%
df["First Score"]=df["First Score"].fillna(df["First Score"].mean())
df["Second Score"]=df["Second Score"].fillna(df["Second Score"].mean())
df["Third Score"]=df["Third Score"].fillna(df["Third Score"].mean())

# %%
df.round(1)
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0         72.7
# 1         90.0          45.0         40.0
# 2         95.0          56.0         80.0
# 3         95.0          43.7         98.0

# %%
import pandas as pd
import numpy as np
dict = {'First Score':[100, 90, np.nan, 95],
 'Second Score': [30, np.nan, 45, 56],
 'Third Score':[52, 40, 80, 98],
 'Fourth Score':[np.nan, np.nan, np.nan, 65]}
df = pd.DataFrame(dict)
df
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0           52           NaN
# 1         90.0           NaN           40           NaN
# 2          NaN          45.0           80           NaN
# 3         95.0          56.0           98          65.0

# %%
df.dropna()
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 3         95.0          56.0           98          65.0

# %%
# iteration in pandas dataframe 
import pandas as pd
data = {
    "Name": ["Abebe", "Hana", "Kebede"],
    "Age": [20, 22, 25],
    "Salary": [12000, 18000, 15000]
}
df = pd.DataFrame(data)
df

for col_name , col_data in df.items():
    print(col_name)
    print("=============")
    print(col_data)
    print("\n")
print("$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$")
for column, value in df.items():
    print("Column Name :", column)
    print(value)
    print("----------------")
# Out:
# Name
# ...
# 0     Abebe
# 1      Hana
# 2    Kebede
# Name: Name, dtype: object
#
#
# Age
# ...
# 0    20
# 1    22
# 2    25
# Name: Age, dtype: int64
#
#
# Salary
# ...
# 0    12000
# 1    18000
# 2    15000
# Name: Salary, dtype: int64
#
#
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# Column Name : Name
# 0     Abebe
# 1      Hana
# 2    Kebede
# Name: Name, dtype: object
# ----------------
# Column Name : Age
# 0    20
# 1    22
# 2    25
# Name: Age, dtype: int64
# ----------------
# Column Name : Salary
# 0    12000
# 1    18000
# 2    15000
# Name: Salary, dtype: int64
# ----------------

# %%
for i, r in df.iterrows():
    print(i)
    print(r)
# Out:
# 0
# Name      Abebe
# Age          20
# Salary    12000
# Name: 0, dtype: object
# 1
# Name       Hana
# Age          22
# Salary    18000
# Name: 1, dtype: object
# 2
# Name      Kebede
# Age           25
# Salary     15000
# Name: 2, dtype: object

# %%
import pandas as pd
dict = {'name':["Dereje", "Dagmawit", "Eyasu", "Yishak"],
 'degree': ["MBA", "BSC", "MSc", "PhD"],
 'score':[90, 40, 80, 98]}
df = pd.DataFrame(dict)
for i, j in df.iterrows():
 print(i, j)
 print()
# Out:
# 0 name      Dereje
# degree       MBA
# score         90
# Name: 0, dtype: object
#
# 1 name      Dagmawit
# degree         BSC
# score           40
# Name: 1, dtype: object
#
# 2 name      Eyasu
# degree      MSc
# score        80
# Name: 2, dtype: object
#
# 3 name      Yishak
# degree       PhD
# score         98
# Name: 3, dtype: object

# %%
columns = list(df)
for i in columns:
 print (df[i][3])
# Out:
# Yishak
# PhD
# 98

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {'Person ID': range(1, 13),
 'Full Name': ['Haileslassie Zeferu Abel', 'Worku Abenezer Girma', 'Abenezer Reta Tamirat', 'Abraham Melisew Fireda', 'Hailu Abraham Niguse', 'Weldetinsae Adonay Gebrehiwot ', 'Debebe Gebremeskel Akin', 'Teferi Amanuel Abebaw', 'Muche Amaniel Kahsu', 'Amanuel Degulaw Zerga', 'Amanuel Abate Nega', 'Amanuel Solomon Hailu'],
 'Income': [80000, 95000, 115000, 75000, 110000, 85000, 100000, 199000,105000, 90000, 80000, 95000]
}
df = pd.DataFrame(data)
df

plt.figure(figsize=(8, 4))
plt.boxplot(df['Income'], vert=False, showfliers=True)
plt.title('Box Plot of Incomes')
plt.xlabel('Income ($000)')
plt.show()
