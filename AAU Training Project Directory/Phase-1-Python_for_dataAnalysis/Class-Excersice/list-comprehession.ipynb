# %%
print("This is list comprehenssion examples")
# Out:
# This is list comprehenssion examples

# %%
data=[1,1,2,3,4,5,6,7,7,8,89,78]

# %%
print(data)
# Out:
# [1, 1, 2, 3, 4, 5, 6, 7, 7, 8, 89, 78]

# %%
results=[value**2 + value/2 for value in data]

# %%
print("The value of the above data is :",results)
# Out:
# The value of the above data is : [1.5, 1.5, 5.0, 10.5, 18.0, 27.5, 39.0, 52.5, 52.5, 68.0, 7965.5, 6123.0]
