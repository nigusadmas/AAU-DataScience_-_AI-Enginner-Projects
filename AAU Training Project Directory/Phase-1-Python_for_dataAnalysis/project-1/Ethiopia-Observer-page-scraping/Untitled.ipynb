# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Display all rows and full text in Jupyter
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)

# Request headers
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/137.0.0.0 Safari/537.36",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
    "Accept-Language": "en-US,en;q=0.9",
    "Referer": "https://google.com/"
}

# Website URL
url = "https://www.ethiopiaobserver.com/"

# Send request
response = requests.get(url, headers=headers)

# Check request status
print("Status Code:", response.status_code)

# Parse HTML
soup = BeautifulSoup(response.text, "html.parser")

# Lists to store data
title_list = []
image_list = []

# Find all articles
articles = soup.find_all("article")

# Extract data
for article in articles:
    h2_tag = article.find("h2")
    image_tag = article.find("img")

    if h2_tag and image_tag:
        a_tag = h2_tag.find("a")

        if a_tag:
            title = a_tag.text.strip()
            image_url = image_tag.get("src", "")

            title_list.append(title)
            image_list.append(image_url)

# Create DataFrame
df = pd.DataFrame({
    "Title": title_list,
    "Image_URL": image_list
})

# Display DataFrame
print("\nTotal Articles:", len(df))
print(df)

# Save to CSV
df.to_csv(
    "ethiopia_observer_articles.csv",
    index=False,
    encoding="utf-8-sig"
)

print("\nCSV file saved successfully!")
# Out:
# Status Code: 200
#
# Total Articles: 13
#                                                                              Title  \
# 0             Independent candidate arrested weeks after withdrawing from election
# 1                                             ከአሜሪካ እና ኢራን ስምምነት አትራፊው ማነው? ተጎጂውስ?
# 2                                                          የዓለም ዋንጫ እና የአባቢዮን ትዝታዬ
# 3             Independent candidate arrested weeks after withdrawing from election
# 4                                             ከአሜሪካ እና ኢራን ስምምነት አትራፊው ማነው? ተጎጂውስ?
# 5                                                          የዓለም ዋንጫ እና የአባቢዮን ትዝታዬ
# 6                          Pope appoints new leader of Catholic Church in Ethiopia
# 7             Shewit Mezgebo’s comeback sparks debate over authorship, attribution
# 8     Tigray authorities reportedly preparing mandatory military conscription plan
# 9                      French journalist Augustine Passilly expelled from Ethiopia
# 10                                                                   የትራምፕ አለም ዋንጫ
# 11                                                                        ከሃረር ባቢሌ
# 12  Drone strikes in Tigray kill unspecified number amid fears of renewed conflict
#
#                                                                                                                                                       Image_URL
# 0               https://i0.wp.com/www.ethiopiaobserver.com/wp-content/uploads/2026/06/8775d5c9-d64c-452c-ab97-dc529f95b96d_2048x2048.jpg?resize=960%2C450&ssl=1
# 1                                                     https://i0.wp.com/www.ethiopiaobserver.com/wp-content/uploads/2026/06/2465768.webp?resize=836%2C450&ssl=1
# 2                                                     https://www.ethiopiaobserver.com/wp-content/uploads/2026/06/db923ae711d9f4b856bf40ea54874e5f-960x450.avif
# 3               https://i0.wp.com/www.ethiopiaobserver.com/wp-content/uploads/2026/06/8775d5c9-d64c-452c-ab97-dc529f95b96d_2048x2048.jpg?resize=300%2C300&ssl=1
# 4                                                     https://i0.wp.com/www.ethiopiaobserver.com/wp-content/uploads/2026/06/2465768.webp?resize=300%2C300&ssl=1
# 5                                                     https://www.ethiopiaobserver.com/wp-content/uploads/2026/06/db923ae711d9f4b856bf40ea54874e5f-300x300.avif
# 6                           https://i0.wp.com/www.ethiopiaobserver.com/wp-content/uploads/2026/06/cq5dam.thumbnail.cropped.1500.844.jpeg?resize=300%2C300&ssl=1
# 7           https://i0.wp.com/www.ethiopiaobserver.com/wp-content/uploads/2026/06/701701764_122166229346902724_5823160685899128217_n.jpg?resize=300%2C300&ssl=1
# 8   https://i0.wp.com/www.ethiopiaobserver.com/wp-content/uploads/2021/02/116742060_144487122_3614330201998463_7629002977772511586_o.jpg?resize=300%2C300&ssl=1
# 9               https://i0.wp.com/www.ethiopiaobserver.com/wp-content/uploads/2026/06/field_media_tv5_jwplayer_field-2932356-6463383.jpg?resize=300%2C300&ssl=1
# 10            https://i0.wp.com/www.ethiopiaobserver.com/wp-content/uploads/2026/06/719874205_1586414489513484_7478907581349611026_n.jpg?resize=300%2C300&ssl=1
# 11                                         https://i0.wp.com/www.ethiopiaobserver.com/wp-content/uploads/2026/06/Babile-camel-market.jpg?resize=300%2C300&ssl=1
# 12                                                         https://i0.wp.com/www.ethiopiaobserver.com/wp-content/uploads/2022/08/816.jpg?resize=300%2C300&ssl=1
#
# CSV file saved successfully!
