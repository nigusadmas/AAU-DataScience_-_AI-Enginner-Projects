# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Display all rows and full text in Jupyter
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)

# Request headers
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/137.0.0.0 Safari/537.36",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
    "Accept-Language": "en-US,en;q=0.9",
    "Referer": "https://google.com/"
}

# Website URL
url = "https://www.ethiopiaobserver.com/"

# Send request
response = requests.get(url, headers=headers)

# Check request status
print("Status Code:", response.status_code)

# Parse HTML
soup = BeautifulSoup(response.text, "html.parser")

# Lists to store data
title_list = []
image_list = []

# Find all articles
articles = soup.find_all("article")

# Extract data
for article in articles:
    h2_tag = article.find("h2")
    image_tag = article.find("img")

    if h2_tag and image_tag:
        a_tag = h2_tag.find("a")

        if a_tag:
            title = a_tag.text.strip()
            image_url = image_tag.get("src", "")

            title_list.append(title)
            image_list.append(image_url)

# Create DataFrame
df = pd.DataFrame({
    "Title": title_list,
    "Image_URL": image_list
})

# Display DataFrame
print("\nTotal Articles:", len(df))
print(df)

# Save to CSV
df.to_csv(
    "ethiopia_observer_articles.csv",
    index=False,
    encoding="utf-8-sig"
)

print("\nCSV file saved successfully!")
# Out:
#                                            image_list
# 0   https://i0.wp.com/www.ethiopiaobserver.com/wp-...
# 1   https://i0.wp.com/www.ethiopiaobserver.com/wp-...
# 2   https://www.ethiopiaobserver.com/wp-content/up...
# 3   https://i0.wp.com/www.ethiopiaobserver.com/wp-...
# 4   https://i0.wp.com/www.ethiopiaobserver.com/wp-...
# 5   https://www.ethiopiaobserver.com/wp-content/up...
# 6   https://i0.wp.com/www.ethiopiaobserver.com/wp-...
# 7   https://i0.wp.com/www.ethiopiaobserver.com/wp-...
# 8   https://i0.wp.com/www.ethiopiaobserver.com/wp-...
# 9   https://i0.wp.com/www.ethiopiaobserver.com/wp-...
# 10  https://i0.wp.com/www.ethiopiaobserver.com/wp-...
# 11  https://i0.wp.com/www.ethiopiaobserver.com/wp-...
# 12  https://i0.wp.com/www.ethiopiaobserver.com/wp-...
# ['Independent candidate arrested weeks after withdrawing from election', 'ከአሜሪካ እና ኢራን ስምምነት አትራፊው ማነው? ተጎጂውስ?', 'የዓለም ዋንጫ እና የአባቢዮን ትዝታዬ', 'Independent candidate arrested weeks after withdrawing from election', 'ከአሜሪካ እና ኢራን ስምምነት አትራፊው ማነው? ተጎጂውስ?', 'የዓለም ዋንጫ እና የአባቢዮን ትዝታዬ', 'Pope appoints new leader of Catholic Church in Ethiopia', 'Shewit Mezgebo’s comeback sparks debate over authorship, attribution', 'Tigray authorities reportedly preparing mandatory military conscription plan', 'French journalist Augustine Passilly expelled from Ethiopia', 'የትራምፕ አለም ዋንጫ', 'ከሃረር ባቢሌ', 'Drone strikes in Tigray kill unspecified number amid fears of renewed conflict']
