# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://newbusinessethiopia.com/"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/137.0.0.0 Safari/537.36",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
    "Accept-Language": "en-US,en;q=0.5",
    "Referer": "https://www.google.com/"
}

response = requests.get(url, headers=headers, timeout=30)

print("Status Code:", response.status_code)

soup = BeautifulSoup(response.text, "html.parser")
data = []

for a in soup.select("nav a[href]"):
    category = a.get_text(strip=True)
    link = a.get("href")

    if category:
        data.append({
            "Category": category,
            "Link": link
        })

df = pd.DataFrame(data)

print(df)

df.to_csv("categories.csv", index=False, encoding="utf-8-sig")

print("CSV saved successfully!")
# Out:
# Status Code: 200
#                  Category                                               Link
# 0                    Home                   https://newbusinessethiopia.com/
# 1              Investment  https://newbusinessethiopia.com/topics/investm...
# 2             Hospitality  https://newbusinessethiopia.com/topics/hospita...
# 3                  Mining     https://newbusinessethiopia.com/topics/mining/
# 4               Oil & Gas    https://newbusinessethiopia.com/topics/oil-gas/
# 5                  Energy     https://newbusinessethiopia.com/topics/energy/
# 6                 Finance    https://newbusinessethiopia.com/topics/finance/
# 7                   Trade      https://newbusinessethiopia.com/topics/trade/
# 8                Politics   https://newbusinessethiopia.com/topics/politics/
# 9       Culture & Tourism  https://newbusinessethiopia.com/topics/culture...
# 10                 Energy     https://newbusinessethiopia.com/topics/energy/
# 11                 Travel     https://newbusinessethiopia.com/topics/travel/
# 12           Construction  https://newbusinessethiopia.com/topics/constru...
# 13                 Health     https://newbusinessethiopia.com/topics/health/
# 14             NBE Videos  https://newbusinessethiopia.com/investment/nbe...
# 15               NBE Blog   https://newbusinessethiopia.com/topics/nbe-blog/
# 16           PR Solutions                      https://behakprsolutions.com/
# 17  Due Diligence Service  https://newbusinessethiopia.com/due-diligence-...
# 18               About Us          https://newbusinessethiopia.com/about-us/
# 19             Contact Us        https://newbusinessethiopia.com/contact-us/
# CSV saved successfully!
