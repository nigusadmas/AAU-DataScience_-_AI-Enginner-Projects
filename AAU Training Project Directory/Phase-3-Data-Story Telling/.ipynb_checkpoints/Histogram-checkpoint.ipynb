# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x=np.random.normal(10,5,50)

# %%
# print(x)

# %%
plt.hist(x)
plt.show()

# %%
scores = [45, 50, 52, 55, 60, 62, 65,
          68, 70, 72, 75, 78, 80,
          82, 85, 90]

plt.hist(scores)
plt.title("Student Score Distribution")
plt.xlabel("Scores")
plt.ylabel("Number of Students")
plt.show()
