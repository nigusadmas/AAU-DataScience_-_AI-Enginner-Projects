# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movies=pd.read_csv("movies_updated.csv")
# movies.head()

# %%
sns.set_theme()

# %%
# Exercise 1
# Tasks
# 1. Create a new feature called ROI:

# ROI = (gross - budget) / budget
movies["ROI"]=(movies["gross"]-movies["budget"])/movies["budget"]
movies["ROI"].head()


# 2. Remove movies with missing values in budget , gross , or score .
movies["budget"]=movies["budget"].astype(int)
movies["gross"]=movies["gross"].astype(int)
movies = movies.dropna(subset=['budget', 'gross', 'score'])

# 3. Create a scatter plot that simultaneously shows:
# Budget
# Gross Revenue
# Movie Score
# Number of Votes
plt.figure(figsize=(12,8))
sns.scatterplot(
    data=movies,
    x="budget",
    y="gross",
    size="votes",
    hue="score",
    alpha=1
)

movies = movies[movies["budget"] > 0]

plt.xscale("log")
plt.yscale("log")

 # 4. Apply appropriate transformations if necessary to improve readability.

plt.title("Movie Budget vs Gross Revenue")
plt.xlabel("Budget(Log Scale)")
plt.ylabel("Gross Revenue (Log Scale)")
plt.legend()
plt.show()

# 5. Identify and annotate the 10 movies with the highest ROI.
top_roi = movies.sort_values(
    "ROI",
    ascending=False
).head(10)
 
# top_roi
plt.figure(figsize=(12,7))

sns.barplot(
    data=top_roi,
    x="ROI",
    y="name")
plt.title("Top 10 Movies With Highest ROI")
plt.xlabel("ROI")
plt.ylabel("Movie")
# Add annotations
for i,value in enumerate(top_roi["ROI"]):
    plt.text(
        value,
        i,
        round(value,2))
plt.show()
# 6. Create a second visualization that compares ROI distributions across the top 10 genres
top_genres = (
    movies["genre"]
    .value_counts()
    .head(10)
    .index)
genre_roi = movies[movies["genre"].isin(top_genres)]
plt.figure(figsize=(14,8))
sns.boxplot(
    data=genre_roi,
    x="genre",
    y="ROI")
plt.xticks(rotation=45)
plt.title("ROI Distribution Across Top Genres")
plt.xlabel("Genre")
plt.ylabel("ROI")
plt.show()


# # by movie count.
# # 7. Based on your visualizations, answer the following questions:
# # Do larger budgets generally result in higher revenue?
# # Which genre appears to generate the highest returns relative to investment?
# # Are highly rated movies always financially successful?
# Out:
#                              name rating   genre  year  \
# 3459      The Blair Witch Project      R  Horror  1999
# 2093                  El Mariachi      R  Action  1992
# 2467                       Clerks      R  Comedy  1994
# 3233        In the Company of Men      R  Comedy  1997
# 209    E.T. the Extra-Terrestrial     PG  Family  1982
# 3089               The Full Monty      R  Comedy  1997
# 5                 Friday the 13th      R  Horror  1980
# 2458  Four Weddings and a Funeral      R  Comedy  1994
# 3291                           Pi      R   Drama  1998
# 1684                      Slacker      R  Comedy  1990
#
#                                 released  score   votes            director  \
# 3459       July 30, 1999 (United States)    6.5  239000       Daniel Myrick
# 2093   February 26, 1993 (United States)    6.9   64000    Robert Rodriguez
# 2467           November 9, 1994 (France)    7.7  214000         Kevin Smith
# 3233      August 1, 1997 (United States)    7.2   13000         Neil LaBute
# 209        June 11, 1982 (United States)    7.8  381000    Steven Spielberg
# 3089  September 19, 1997 (United States)    7.2  101000      Peter Cattaneo
# 5            May 9, 1980 (United States)    6.4  123000  Sean S. Cunningham
# 2458      April 15, 1994 (United States)    7.1  144000         Mike Newell
# 3291       July 10, 1998 (United States)    7.4  173000    Darren Aronofsky
# 1684        July 5, 1991 (United States)    7.1   20000   Richard Linklater
#
#                  writer               star         country    budget  \
# 3459      Daniel Myrick    Heather Donahue   United States     60000
# 2093   Robert Rodriguez    Carlos Gallardo          Mexico      7000
# 2467        Kevin Smith   Brian O'Halloran   United States     27000
# 3233        Neil LaBute      Aaron Eckhart          Canada     25000
# 209    Melissa Mathison       Henry Thomas   United States  10500000
# 3089      Simon Beaufoy     Robert Carlyle  United Kingdom   3500000
# 5         Victor Miller       Betsy Palmer   United States    550000
# 2458     Richard Curtis         Hugh Grant  United Kingdom   4400000
# 3291   Darren Aronofsky      Sean Gullette   United States     60000
# 1684  Richard Linklater  Richard Linklater   United States     23000
#
#           gross                           company runtime,,          ROI
# 3459  248639099                       Haxan Films     81.0,  4142.984983
# 2093    2040920                 Columbia Pictures     81.0,   290.560000
# 2467    3151130            View Askew Productions     92.0,   115.708519
# 3233    2804473  Alliance Atlantis Communications     97.0,   111.178920
# 209   792910554                Universal Pictures    115.0,    74.515291
# 3089  257938649                     Redwave Films     91.0,    72.696757
# 5      39754601                Paramount Pictures     95.0,    71.281093
# 2458  245700832     PolyGram Filmed Entertainment    117.0,    54.841098
# 3291    3221152                 Harvest Filmworks     84.0,    52.685867
# 1684    1228108             Detour Filmproduction     97.0,    52.396000
