# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import matplotlib.pyplot as plt
#       3 # 1. ዳታውን በምርት ከፋፍሎ የሽያጭ ድምር ማውጣት
# ----> 4 product_sales = df.groupby("Product")["Total_Sales"].sum().sort_values(ascending=True)
#       6 # 2. የምስሉን መጠን ማስተካከል
#       7 plt.figure(figsize=(10, 6))
#
# NameError: name 'df' is not defined
