# %%
import pandas as pd

# %%
import numpy as np

# %%
students=pd.DataFrame({
    "name": ["Abel", "Hana", "Abel", None],
    "age": [21, np.nan, 21, 23],
    "department": ["CS", "IT", "CS", "SE"],
    "gpa": [3.5, 3.8, 3.5, np.nan]
    
})
