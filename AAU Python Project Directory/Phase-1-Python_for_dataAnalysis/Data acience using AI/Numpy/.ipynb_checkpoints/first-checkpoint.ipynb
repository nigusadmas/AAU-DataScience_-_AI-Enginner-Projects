# %%
import numpy as np

first=['hello','world']

double=np.array(first)

print(double)

print(first*2)

num=[3,5,7,9,76]
double_num=np.array(num)

double_number=double_num*2

print(double_number)
# Out:
# ['hello' 'world']
# ['hello', 'world', 'hello', 'world']
# [ 3  5  7  9 76]
