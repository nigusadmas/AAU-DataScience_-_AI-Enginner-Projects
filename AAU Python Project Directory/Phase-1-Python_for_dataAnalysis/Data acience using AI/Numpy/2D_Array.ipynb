# %%
import numpy as np

# %%
Matrix=np.array([
    [10,20,30,40,50],
    [20,30,40,50,60]
])

# %%
print(Matrix)
# Out:
# [[10 20 30 40 50]
#  [20 30 40 50 60]]

# %%
print(Matrix*2)
# Out:
# [[ 20  40  60  80 100]
#  [ 40  60  80 100 120]]

# %%
print(Matrix.shape)
# Out:
# (2, 5)

# %%
Three_D_Array=np.array([
    [
       [10,20,30,40,50],
       [20,30,40,50,60]
        
    ],
    [
        [10,20,30,40,50],
        [20,30,40,50,60]
    ]
    
])

# %%
print(Three_D_Array.shape)
# Out:
# (2, 2, 5)

# %%
# Addational Example

# %%
# Calculate mean of a given list
Grade=[69,89,98,78,89]

# %%
mean=np.mean(Grade)

# %%
print(mean)
# Out:
# 84.6

# %%
# Calculate Maximum of a given list

# %%
maximum=np.max(Grade)

# %%
print(maximum)
# Out:
# 98

# %%
# Calculate Minimum of a given list

# %%
minimum=np.min(Grade)

# %%
print(minimum)
# Out:
# 69
