# %%
from bs4 import BeautifulSoup

html_services="""
<p class="service-name">React Frontend</p>
<p class="service-name">Node.js Backend</p>
<p class="service-name">UI/UX Design</p>
"""

# print(html_services)

soup=BeautifulSoup(html_services,"html.parser")

# print(soup)

# single_para=soup.find("p" , class_="service-name")
# print(single_para)

all_para=soup.find_all("p",class_="service-name")
# print(all_para)

for para in all_para:
    print(para.text)
