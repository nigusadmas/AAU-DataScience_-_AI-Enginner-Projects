# %%
import pandas as pd

# %%
# የሰዎችን መረጃ በፓይተን ዲክሽነሪ አዘጋጀን

# %%
Data={
    "Name": ["ንጉስ", "አልማዝ", "በቀለ"],
    "Age": [22, 25, 28],
    "Skill": ["Python", "JavaScript", "HTML"]
}

# %%
df=pd.DataFrame(Data)

# %%
print(df,index=False)
# Out:
#    Name  Age       Skill
# 0   ንጉስ   22      Python
# 1  አልማዝ   25  JavaScript
# 2   በቀለ   28        HTML
