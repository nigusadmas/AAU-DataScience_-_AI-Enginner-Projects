# %%
import matplotlib.pyplot as plt

# %%
#this code show my understanding in pandas , numpy, matplot,web scraping from 100%

# %%
course=["pandas","matplot","numpy","web-scrap"]

# %%
shares=[95,98,99,98]

# %%
plt.pie(shares,labels=course,autopct='%1.1f%%',startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x28928258a50>,
#   <matplotlib.patches.Wedge at 0x28928258e10>,
#   <matplotlib.patches.Wedge at 0x289282591d0>,
#   <matplotlib.patches.Wedge at 0x28928259590>],
#  [Text(-0.7619969131790837, 0.7933225726686138, 'pandas'),
#   Text(-0.805495239200383, -0.7491177608530704, 'matplot'),
#   Text(0.7619971716763485, -0.7933223243784618, 'numpy'),
#   Text(0.7809429463074427, 0.7746793624543324, 'web-scrap')],
#  [Text(-0.41563467991586384, 0.43272140327378933, '24.4%'),
#   Text(-0.43936103956384526, -0.40860968773803835, '25.1%'),
#   Text(0.41563482091437187, -0.4327212678427973, '25.4%'),
#   Text(0.42596887980405956, 0.422552379520545, '25.1%')])

# %%
plt.title("My Understanding Of Couses in pie")
