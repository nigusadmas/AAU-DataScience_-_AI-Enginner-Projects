# %%
print("The following are tuple codes")

# %%
print("TUPLE: \n Tuple is a built in datatype that contain many elements in one variable \n the elements in the tuple can not be modified(inserted,changed ......)")
# Out:
# TUPLE:
#  Tuple is a built in datatype that contain many elements in one variable
#  the elements in the tuple can not be modified(inserted,changed ......)

# %%
tupleList=("tuple" ,"list" ,"string" ,"set" ,"dictionary" , )
print(tupleList)
# tupleList(1)="integer"
# print(tupleList)
# Out:
# ('tuple', 'list', 'string', 'set', 'dictionary')
