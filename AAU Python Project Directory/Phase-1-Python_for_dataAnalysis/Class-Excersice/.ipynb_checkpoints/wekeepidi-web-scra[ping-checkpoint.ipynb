# %%
import requests
from bs4 import BeautifulSoup

url = "https://en.wikipedia.org/wiki/Ethiopia"

response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
soup = BeautifulSoup(response.text, "html.parser")

main_sections = soup.select("li.vector-toc-level-1 > a .vector-toc-text")

for item in main_sections:
    print(item.get_text(strip=True))
# Out:
# (Top)
# 1Names
# 2History
# 2.1Prehistory
# 2.2Antiquity
# 2.3Middle Ages
# 2.4Early Modern Period (1632–1855)
# 2.5Age of Imperialism (1855–1916)
# 2.6Haile Selassie I era (1916–1974)
# 2.7Derg era (1974–1991)
# 2.8Federal Democratic Republic (1991–present)
# 3Geography
# 3.1Climate
# 3.2Biodiversity
# 4Government and politics
# 4.1Government
# 4.2Politics
# 4.3Administrative divisions
# 4.4Foreign relations
# 4.5Military
# 4.6Law enforcement
# 5Economy
# 5.1Energy and hydropower
# 5.2Agriculture
# 5.3Exports
# 5.4Transport
# 5.5Science and technology
# 6Demographics
# 6.1Urbanization
# 6.1.1Rural and urban life
# 6.2Languages
# 6.2.1Script
# 6.3Religion
# 6.4Health
# 6.5Education
# 7Culture
# 7.1Holidays
# 7.2Art and architecture
# 7.3Literature
# 7.4Music
# 7.5Calendar
# 7.6Media
# 7.7Cinema
# 7.8Cuisine
# 7.9Sport
# 8See also
# 9Notes
# 10References
# 10.1Citations
# 10.2General sources
# 11Further reading
# 12External links
