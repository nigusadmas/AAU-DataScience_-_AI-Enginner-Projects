# %%
import requests
from bs4 import BeautifulSoup
html_doc=requests.get('https://www.worldometers.info/coronavirus/')
soup=BeautifulSoup(html_doc.content, "html.parser")
all_table=soup.find("table")
# print(all_table)
t_head=all_table.find("thead")
# print(t_head)
t_row=t_head.find("tr")
# print(t_row)
thead=t_row.find_all("th")
# print(thead)
data=[]
for item in thead:
    data.append(item.text)
    print(data)
    print("____________________________________________________")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 14
#      12 # print(thead)
#      13 data=[]
# ---> 14 for i, item in thead:
#      15     data.append(item.text)
#      16     print(data)
#
# ValueError: not enough values to unpack (expected 2, got 1)
