# %%
print("This is a list:\n \t List is a built in data type in python used for creating many \n \t elements in one variables")
# Out:
# This is a list:
#  	 List is a built in data type in python used for creating many
#  	 elements in one variables

# %%
listFruits = ["banana", "mango", "avocado", "apple", "avocado", "tomato"]
print(listFruits)
print(listFruits[1])
print(listFruits[-3])
print(listFruits[1:])
print(listFruits[-1:])
print(listFruits[-3:4])
print(listFruits[-3:3])
print(listFruits[:-1])
listFruits[0]=["selata"]
# Out:
# ['banana', 'mango', 'avocado', 'apple', 'avocado', 'tomato']
# mango
# apple
# ['mango', 'avocado', 'apple', 'avocado', 'tomato']
# ['tomato']
# ['apple']
# []
# ['banana', 'mango', 'avocado', 'apple', 'avocado']
