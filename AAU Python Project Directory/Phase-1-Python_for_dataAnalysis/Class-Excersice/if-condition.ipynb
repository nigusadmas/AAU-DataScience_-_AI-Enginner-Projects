# %%
print("this the first code /program in jupyterLab")
# Out:
# this the first code /program in jupyterLab

# %%
num = 10
if (num > 21):
    print(num, "is greater than 21")
else:
    print(num, "is less than 21")
# Out:
# 10 is less than 21

# %%
number = int(input("enter the number"))
if (number % 2 == 0):
    print("the input number is even")
else:
    print("the input number is odd")

# %%
print("Ending the if program")

# %% [markdown]
# ###### print("The next code will be elif statment that display the grade of the \n students")

# %%
print("A program that displays grade for student")
mark = int(input("Enter mark:"))
if (mark >= 90):
    print("Your Grade : A+")
elif (mark >= 85):
    print("Your Grade : A")
elif (mark >= 80):
    print("Your Grade : A-")
elif (mark >= 75):
    print("Your Grade : B+")
elif (mark >= 70):
    print("Your Grade : B")
elif (mark >= 65):
    print("Your Grade : B-")
elif (mark >= 60):
    print("Your Grade : C+")
elif (mark >= 55):
    print("Your Grade : C")
elif (mark >= 50):
    print("Your Grade : C-")
elif (mark >= 40):
    print("Your Grade : D")
else:
    print("Your Grade : F")
    print("Please add the course")
