# %%
# This is a program to show single column selection

# %%
import pandas as pd 
  
data = {'Name':['Eyob', 'Michael', 'Bethelhem', 'Martha'], 
        'Age':[27, 24, 22, 32], 
        'Address':[ 'Addis Ababa', 'Mekelle', 'Bahirdar', 
'Shashemene'], 
        'Qualification':['MSc', 'MA', 'MCA', 'PhD']} 
  
df = pd.DataFrame(data) 
print(df[['Address']]) 
print("======================================")
print(df[['Age']]) 
print("======================================")
print(df[['Name']]) 
print("======================================")
print(df[['Qualification']]) 
print("======================================")
# Out:
#        Address
# 0  Addis Ababa
# 1      Mekelle
# 2     Bahirdar
# 3   Shashemene
# ...
#    Age
# 0   27
# 1   24
# 2   22
# 3   32
# ...
#         Name
# 0       Eyob
# 1    Michael
# 2  Bethelhem
# 3     Martha
# ...
#   Qualification
# 0           MSc
# 1            MA
# 2           MCA
# 3           PhD
# ...
