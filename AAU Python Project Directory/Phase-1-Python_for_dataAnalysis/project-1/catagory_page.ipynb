# %%
import pandas as pd

import requests

from bs4 import BeautifulSoup

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

url="https://newbusinessethiopia.com/topics/investment/"

response=requests.get(url,headers=headers)

soup=BeautifulSoup(response.text,"html.parser")

# print(soup)

All_catagory=soup.find_all("ul" , class_="nbe-primary-menu")

# print(catagory)

catagory_list=[]

for catagory in All_catagory:
    categories=catagory.find_all("li")

    for li in categories:  # Loop through each li element
        catagory_list.append(li.text.strip())

# %%
print(catagory_list)
# Out:
# ['Home', 'Investment', 'Hospitality', 'Mining', 'Oil & Gas', 'Energy', 'Finance', 'Trade', 'Politics', 'Culture & Tourism', 'Energy', 'Travel', 'Construction', 'Health', 'NBE Videos', 'NBE Blog', 'PR Solutions', 'Due Diligence Service', 'About Us', 'Contact Us']
