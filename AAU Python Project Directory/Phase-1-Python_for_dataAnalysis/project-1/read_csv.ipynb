# %%
import pandas as pd

# %%
df=pd.read_csv("All_Investment_Page.csv",encoding="utf-8")

# %%
print(df.head())
# Out:
#         date_list                                         image_list  \
# 0    May 12, 2026  https://newbusinessethiopia.com/wp-content/upl...
# 1  April 23, 2026  https://newbusinessethiopia.com/wp-content/upl...
# 2  April 13, 2026  https://newbusinessethiopia.com/wp-content/upl...
# 3   April 6, 2026  https://newbusinessethiopia.com/wp-content/upl...
# 4   April 6, 2026  https://newbusinessethiopia.com/wp-content/upl...
#
#                                           title_list  \
# 0  Ming Yang Group to Invest $14 Billion in Solar...
# 1   EU, Germany to Help Ethiopia Grow Private Sector
# 2  Why Due Diligence Is Critical Before Entering ...
# 3  Movement, Connectivity, and Travel Logistics i...
# 4  New Ceramic Factory to Boost Ethiopia’s Produc...
#
#                                            para_list
# 0  Ming Yang Group to Invest $14 Billion in Solar...
# 1  EU, Germany to Help Ethiopia Grow Private Sect...
# 2  Why Due Diligence Is Critical Before Entering ...
# ...
