# %%
import pandas as pd

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

# %%
url="https://newbusinessethiopia.com/topics/investment/"

# %%
response=requests.get(url,headers=headers)

# %%
soup=BeautifulSoup(response.text,"html.parser")

# %%
# print(soup)

# %%
All_catagory=soup.find_all("ul" , class_="nbe-primary-menu")

# %%
# print(catagory)

# %%
catagory_list=[]

# %%
for catagory in All_catagory:
    categories=catagory.find("li")
    print(categories)
# Out:
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-home menu-item-46228" id="menu-item-46228"><a href="https://newbusinessethiopia.com/"><span class="screen-reader-text">Home</span></a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-home menu-item-46228"><a href="https://newbusinessethiopia.com/">Home</a></li>
# <li><a href="https://newbusinessethiopia.com/topics/investment/">Investment</a></li>
# <li><a href="https://newbusinessethiopia.com/topics/travel/">Travel</a></li>
# <li><a href="https://newbusinessethiopia.com/topics/health/">Health</a></li>
