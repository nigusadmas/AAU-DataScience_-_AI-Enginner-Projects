# %%
import numpy as np

# %%
print(np.__version__)
# Out:
# 2.1.3

# %%
x1 = 2
x2 = 3
w1 = 0.5
w2 = 0.2
bias = 1
# then calculate z
z=(x1*w1) + (x2*w2) + bias
print("Weighted sum:", z)
# Out:
# Weighted sum: 2.6

# %%
# ReLU Activation
# negative number → 0
# positive number → unchanged
# for example:-
    -6 ->0
     6 ->6
